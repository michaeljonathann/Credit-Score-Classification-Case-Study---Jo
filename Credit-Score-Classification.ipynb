# %% [markdown]
# #### Import Library & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go
# import plotly.io as pio
# pio.templates.default = "plotly_white"

# %%
df = pd.read_csv("Credit-Score-Data/train.csv")
df
# Out:
#            ID  Customer_ID  Month           Name   Age          SSN  \
# 0        5634         3392      1  Aaron Maashoh  23.0  821000265.0
# 1        5635         3392      2  Aaron Maashoh  23.0  821000265.0
# 2        5636         3392      3  Aaron Maashoh  23.0  821000265.0
# 3        5637         3392      4  Aaron Maashoh  23.0  821000265.0
# 4        5638         3392      5  Aaron Maashoh  23.0  821000265.0
# ...       ...          ...    ...            ...   ...          ...
# 99995  155625        37932      4          Nicks  25.0   78735990.0
# 99996  155626        37932      5          Nicks  25.0   78735990.0
# 99997  155627        37932      6          Nicks  25.0   78735990.0
# 99998  155628        37932      7          Nicks  25.0   78735990.0
# 99999  155629        37932      8          Nicks  25.0   78735990.0
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0      Scientist       19114.12            1824.843333                3.0
# ...

# %% [markdown]
# #### Cleaning Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
df["Credit_Score"].value_counts()
# Out:
# Credit_Score
# Standard    53174
# Poor        28998
# Good        17828
# Name: count, dtype: int64

# %% [markdown]
# #### Data Exploration

# %%
def viz_barplot(data, target_column, feature_column, x_axis_rotation=45, width=12, height=6):
    plt.figure(figsize=(width, height))
    ax = sns.countplot(data = data, x= feature_column, hue = target_column)
    ax.set_ylabel('Credit Score')
    ax.set_xlabel(feature_column)
    plt.xticks(rotation = x_axis_rotation)
    plt.title(f'{target_column} based on {feature_column}')
    plt.show()

# %%
viz_barplot(data = df, target_column = 'Credit_Score', feature_column = 'Occupation')

# %% [markdown]
# > Summary: tidak terlalu banyak perbedaan jumlah credit score jika dilihat dari pekerjaan yang ada di data

# %%
def viz_boxplot(data, target_column, feature_column, width=12, height=6):
    color_map = {"Standard": "yellow", "Poor": "red", "Good": "green"}
    plt.figure(figsize=(width, height))
    ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)
    ax.set_ylabel('Credit Score')
    ax.set_xlabel(feature_column)
    plt.title(f'{target_column} based on {feature_column}')
    plt.show()

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Annual_Income', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %% [markdown]
# > Summary: semakin baik jumlah pendapatan tahunan, semakin baik pula jumlah credit score

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Monthly_Inhand_Salary', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %% [markdown]
# > Summary: sama seperti pendapatan tahunan, jumlah pendapatan bulanan yang semakin baik akan meningkatkan jumlah credit score

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Num_Bank_Accounts', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %% [markdown]
# > Summary: Mempunyai bank account di bawah 5, jumlah credit score membaik. Di atas 5, jumlah credit score buruk.

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Num_Credit_Card', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %% [markdown]
# > Summary: Memiliki lebih banyak kartu kredit tidak akan berdampak positif pada skor kredit Anda. Memiliki 3 - 5 kartu kredit cukup baik untuk skor kredit Anda.

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Interest_Rate', width=6, height=3)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Num_of_Loan', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Delay_from_due_date', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Num_of_Delayed_Payment', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Outstanding_Debt', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Credit_Utilization_Ratio', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Credit_History_Age', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Total_EMI_per_month', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Amount_invested_monthly', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %%
viz_boxplot(data = df, target_column='Credit_Score', feature_column='Monthly_Balance', width=8, height=4)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_19320\3997595870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=data, x=feature_column, y=target_column, palette=color_map)

# %% [markdown]
# #### Credit Score Classification Model

# %%
df["Credit_Mix"] = df["Credit_Mix"].map({"Standard" : 1, "Good" : 2, "Bad" : 0})

# %%
from sklearn.model_selection import train_test_split
x = np.array(df[["Annual_Income", "Monthly_Inhand_Salary", 
                   "Num_Bank_Accounts", "Num_Credit_Card", 
                   "Interest_Rate", "Num_of_Loan", 
                   "Delay_from_due_date", "Num_of_Delayed_Payment", 
                   "Credit_Mix", "Outstanding_Debt", 
                   "Credit_History_Age", "Monthly_Balance"]])
y = np.array(df[["Credit_Score"]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size=0.2, 
                                                    random_state=42)
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# d:\Mic\New-All-Programming-Project\Credit-Score-Classification-Case-Study---Jo\.venv\lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
print("Credit Score Prediction : ")
a = float(input("Annual Income: "))
b = float(input("Monthly Inhand Salary: "))
c = float(input("Number of Bank Accounts: "))
d = float(input("Number of Credit cards: "))
e = float(input("Interest rate: "))
f = float(input("Number of Loans: "))
g = float(input("Average number of days delayed by the person: "))
h = float(input("Number of delayed payments: "))
i = input("Credit Mix (Bad: 0, Standard: 1, Good: 3) : ")
j = float(input("Outstanding Debt: "))
k = float(input("Credit History Age: "))
l = float(input("Monthly Balance: "))

features = np.array([[a, b, c, d, e, f, g, h, i, j, k, l]])
print("Prediksi Credit Score : ", model.predict(features))
# Out:
# Credit Score Prediction :
# Prediksi Credit Score :  ['Good']
